# %% [markdown]
# <a href="https://colab.research.google.com/github/YangliuF95/text-as-data-exercises/blob/main/Python_basics.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Notebook adapted from Mathieu Blondel.

# %% [markdown]
# # Welcome 🐍

# %% [markdown]
# The document that you are reading is not a static web page, but an interactive environment called a notebook, that lets you write and execute code. Notebooks consist of so-called code cells, blocks of one or more Python instructions. For example, here is a code cell that stores the result of a computation (the number of seconds in a day) in a variable and prints its value:
#
# ---
#
# ## ❗Before you start: How to use this notebook
#
# - Run a cell with **Shift + Enter**.
# - If something goes wrong, choose **Runtime → Restart runtime** and then run the cells again from the top.
# - Code comments begin with `#`. They explain what the code is doing.
# - **Please use AI coding tutors, such as Toggle Gemini at the bottom of the page ❇️**. However, make sure you understand the code you submit.

# %%
seconds_in_a_day = 24 * 60 * 60
seconds_in_a_day

# %% [markdown]
# Click on the "play" button to execute the cell. You should be able to see the result. Alternatively, you can also execute the cell by pressing Ctrl + Enter if you are on Windows / Linux or Command + Enter if you are on a Mac.

# %% [markdown]
# Variables that you defined in one cell can later be used in other cells:

# %%
seconds_in_a_week = 7 * seconds_in_a_day
seconds_in_a_week

# %% [markdown]
# Note that the order of execution is important. For instance, if we do not run the cell storing *seconds_in_a_day* beforehand, the above cell will raise an error, as it depends on this variable. To make sure that you run all the cells in the correct order, you can also click on "Runtime" in the top-level menu, then "Run all".

# %% [markdown]
# **Task 1:** Add a cell below this cell: click on this cell then click on "+ Code". In the new cell, compute the number of seconds in a year by reusing the variable *seconds_in_a_day*. Run the new cell.

# %% [markdown]
# # Python

# %% [markdown]
# Python is one of the most popular programming languages for machine learning, both in academia and in industry. As such, it is essential to learn this language for anyone interested in machine learning. In this section, we will review Python basics.

# %% [markdown]
# ## Arithmetic operations

# %% [markdown]
# Python supports the usual arithmetic operators: + (addition), * (multiplication), / (division), ** (power), // (integer division).

# %% [markdown]
# ## Lists

# %% [markdown]
# Lists are a container type for ordered sequences of elements. Lists can be initialized empty

# %%
my_list = []

# %% [markdown]
# or with some initial elements

# %%
my_list = [1, 2, 3]

# %% [markdown]
# Lists have a dynamic size and elements can be added (appended) to them

# %%
my_list.append(4)
my_list

# %% [markdown]
# We can access individual elements of a list (indexing starts from 0)

# %%
my_list[2]

# %% [markdown]
# We can access "slices" of a list using `my_list[i:j]` where `i` is the start of the slice (again, indexing starts from 0) and `j` the end of the slice. For instance:

# %%
my_list[1:3]

# %% [markdown]
# Omitting the second index means that the slice should run until the end of the list

# %%
my_list[1:]

# %% [markdown]
# We can check if an element is in the list using `in`

# %%
5 in my_list

# %% [markdown]
# The length of a list can be obtained using the `len` function

# %%
len(my_list)

# %% [markdown]
# ## Strings

# %% [markdown]
# Strings are used to store text. They can delimited using either single quotes or double quotes

# %%
string1 = "some text"
string2 = 'some other text'

# %% [markdown]
# Strings behave similarly to lists. As such we can access individual elements in exactly the same way

# %%
string1[3]

# %% [markdown]
# and similarly for slices

# %%
string1[5:]

# %% [markdown]
# String concatenation is performed using the `+` operator

# %%
string1 + " " + string2

# %% [markdown]
# ## Conditionals

# %% [markdown]
# As their name indicates, conditionals are a way to execute code depending on whether a condition is True or False. As in other languages, Python supports `if` and `else` but `else if` is contracted into `elif`, as the example below demonstrates.

# %%
my_variable = 5
if my_variable < 0:
  print("negative")
elif my_variable == 0:
  print("null")
else: # my_variable > 0
  print("positive")

# %% [markdown]
# Here `<` and `>` are the strict `less` and `greater than` operators, while `==` is the equality operator (not to be confused with `=`, the variable assignment operator). The operators `<=` and `>=` can be used for less (resp. greater) than or equal comparisons.

# %% [markdown]
# Contrary to other languages, blocks of code are delimited using indentation. Here, we use 2-space indentation but many programmers also use 4-space indentation. Any one is fine as long as you are consistent throughout your code.

# %% [markdown]
# ## Loops

# %% [markdown]
# Loops are a way to execute a block of code multiple times. There are two main types of loops: while loops and for loops.

# %% [markdown]
# While loop

# %%
i = 0
while i < len(my_list):
  print(my_list[i])
  i += 1 # equivalent to i = i + 1

# %% [markdown]
# For loop

# %%
for i in range(len(my_list)):
  print(my_list[i])

# %% [markdown]
# If the goal is simply to iterate over a list, we can do so directly as follows

# %%
for element in my_list:
  print(element)

# %% [markdown]
# ## Functions

# %% [markdown]
# To improve code readability, it is common to separate the code into different blocks, responsible for performing precise actions: functions. A function takes some inputs and process them to return some outputs.

# %%
def square(x):
  return x ** 2

def multiply(a, b):
  return a * b

# Functions can be composed.
square(multiply(3, 2))

# %% [markdown]
# To improve code readability, it is sometimes useful to explicitly name the arguments

# %%
square(multiply(a=3, b=2))

# %% [markdown]
# ## Pandas 🐼: Pandas is a Python library used for working with data sets. It has functions for analyzing, cleaning, exploring, and manipulating data.  Alternatively, you can look at this 10 mins [user guide](https://pandas.pydata.org/docs/user_guide/10min.html)
#
#
#
# In text analysis, we often work with tables where each row is one text and each column gives information about that text.
#
# For example, one column might contain the text itself, while other columns might contain metadata such as the speaker, party, topic, or date.
#
# In Python, we can use the `pandas` package to work with this kind of table.
#
# The most important pandas object is called a **DataFrame**. A DataFrame is like a spreadsheet in Python.

# %%
import pandas as pd

# Create a small toy dataset
data = {
    "speaker": ["Alice", "Bob", "Clara", "David"],
    "party": ["Green", "Conservative", "Green", "Social Democrat"],
    "text": [
        "Climate policy is important for the future.",
        "The economy needs lower taxes and less regulation.",
        "We need stronger action on climate change.",
        "Workers need fair wages and social protection."
    ]
}

# Convert the dictionary into a pandas DataFrame
df = pd.DataFrame(data)

# Show the table
df

# %% [markdown]
# **Task 2:** Look at the table. What does each row represent? What does each column represent?
#
# **Your answer:**

# %%
# Show the first rows of the table
df.head()

# %%
# Check the number of rows and columns
df.shape

# %%
# Show the column names
df.columns

# %% [markdown]
# **Task 3:** How many rows and columns does the dataset have? Which column contains the actual text?
#
# **Your answer:**

# %%
# Add a new column with the number of characters in each text
df["text_length"] = df["text"].str.len()

# Add another column with the number of words in each text
df["word_count"] = df["text"].str.split().str.len()

# Show the updated table
df

# %% [markdown]
# **Task 4:** Which text is the longest? Is it also the text with the most words?
#
# **Your answer:**

# %%
# Calculate the average word count by party
df.groupby("party")["word_count"].mean()

# %%
# Count how many texts mention climate
df["mentions_climate"] = df["text"].str.lower().str.contains("climate")

df

# %%
# Count how many texts mention climate by party
df.groupby("party")["mentions_climate"].sum()

# %% [markdown]
# # Reflection
#
# In this short pandas section, we learned how to:
#
# - create a table of texts,
# - inspect rows and columns,
# - add simple text features,
# - group texts by metadata,
# - search for keywords in text.
#
# These are basic building blocks for many forms of computational text analysis.

# %% [markdown]
# ## Going further if you are interested, not required!!!

# %% [markdown]
# *   List of Python [tutorials](https://wiki.python.org/moin/BeginnersGuide/Programmers)
# * Four-hour [course](https://www.youtube.com/watch?v=rfscVS0vtbw) on Youtube

# %% [markdown]
# * NumPy [reference](https://numpy.org/doc/stable/reference/)
# * SciPy [lectures](https://scipy-lectures.org/)
# *   One-hour [tutorial](https://www.youtube.com/watch?v=QUT1VHiLmmI) on Youtube
